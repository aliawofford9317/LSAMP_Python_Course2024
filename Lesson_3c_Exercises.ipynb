# %% [markdown]
# <a href="https://colab.research.google.com/github/aliawofford9317/LSAMP_Python_Course2024/blob/DanielaaVargas/Lesson_3c_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exercise 1**
#
# Create a 3x3x3 array that contains all random numbers.
# Using the previous array, square all the numbers in the array.

# %%
import numpy as np

# %%
np.random.seed(700)
Array = np.random.randint(10,size=(3,3,3)) #3 dimentional array
Array
# Out:
# array([[[7, 7, 1],
#         [5, 2, 3],
#         [8, 6, 0]],
#
#        [[2, 6, 8],
#         [8, 9, 4],
#         [9, 1, 5]],
#
#        [[4, 3, 2],
#         [3, 0, 1],
#         [2, 8, 6]]])

# %%
SqArray = Array**2 #The square operation on an array is also an array (it is closed)
SqArray
# Out:
# array([[[49, 49,  1],
#         [25,  4,  9],
#         [64, 36,  0]],
#
#        [[ 4, 36, 64],
#         [64, 81, 16],
#         [81,  1, 25]],
#
#        [[16,  9,  4],
#         [ 9,  0,  1],
#         [ 4, 64, 36]]])

# %% [markdown]
# # **Exercise 2**
# Create a new array using `arange`. This array should contain a total of 4 values.
# Select only values in index 2 and index 4.
# Change the value of index 3 to 99

# %%
Arr = np.arange(4,12,2)
Arr
# Out:
# array([ 4,  6,  8, 10])

# %%
print(Arr[1])
print(Arr[3])
Arr[2]=99
Arr
# Out:
# 6
# 10
# array([ 4,  6, 99, 10])

# %% [markdown]
# # **Exercise 3**
# Create a new 4x4 array.
# Select and print only the first two rows.
# Select and print only the last two columns.
# Select only the last two rows and first two columns.
# Reshape the array into a 8x2 array.

# %%
np.random.seed(700)
Cdot = np.random.randint(100,size=(4,4))
Cdot
# Out:
# array([[55,  7, 62, 49],
#        [50, 35, 90, 61],
#        [28,  8, 80, 50],
#        [36, 81, 52,  3]])

# %%
print("The first 2 rows are:\n") #Rows subarray
r = Cdot[:2]
r
# Out:
# The first 2 rows are:
# array([[55,  7, 62, 49],
#        [50, 35, 90, 61]])

# %%
print("\nThe last two columns are:\n") #Columns subarray
c = Cdot[:4,2:4]
c
# Out:
# The last two columns are:
# array([[62, 49],
#        [90, 61],
#        [80, 50],
#        [52,  3]])

# %%
Cdot.shape
# Out:
# (4, 4)

# %%
Cdot[:4,:2]
# Out:
# array([[55,  7],
#        [50, 35],
#        [28,  8],
#        [36, 81]])

# %%
"""I'm not sure how to reshape a 4x4 array to an 8x2 array.
Is it okay if I just generate a new array with the same seed? """
np.random.seed(700)
np.random.randint(100,size=(8,2))
# Out:
# array([[55,  7],
#        [62, 49],
#        [50, 35],
#        [90, 61],
#        [28,  8],
#        [80, 50],
#        [36, 81],
#        [52,  3]])

# %%
"Or should Imaybe delete 2 columns and add 4 rows?"
np.random.seed(700)
DelC = Cdot[:4,:2]  #Deleting 2 columns
row = np.random.randint(100,size=(4,2)) #Creating new rows

np.vstack((DelC, row)) #Adding the new rows
# Out:
# array([[55,  7],
#        [50, 35],
#        [28,  8],
#        [36, 81],
#        [55,  7],
#        [62, 49],
#        [50, 35],
#        [90, 61]])

# %% [markdown]
# # **Exercises for Participation Credit**
#
#
# 1.  Create a new random integer array with Numpy functions. Use a random seed to guarantee the same array every time. Array must be of size (20, 5).
# 2. Calculate the average value of the second column of the array created in exercise.
# 3. Calculate the sum of all elements in columns 3 and 4. You can use built in ufuncs and indexing.

# %%
np.random.seed(10)
Gamma = np.random.randint(100,size=(20,5))
Gamma
# Out:
# array([[ 9, 15, 64, 28, 89],
#        [93, 29,  8, 73,  0],
#        [40, 36, 16, 11, 54],
#        [88, 62, 33, 72, 78],
#        [49, 51, 54, 77, 69],
#        [13, 25, 13, 92, 86],
#        [30, 30, 89, 12, 65],
#        [31, 57, 36, 27, 18],
#        [93, 77, 22, 23, 94],
#        [11, 28, 74, 88,  9],
#        [15, 18, 80, 71, 88],
#        [11, 17, 46,  7, 75],
#        [28, 33, 84, 96, 88],
#        [44,  5,  4, 71, 88],
#        [88, 50, 54, 34, 15],
#        [77, 88, 15,  6, 85],
#        [22, 11, 12, 92, 96],
#        [62, 57, 79, 42, 57],
#        [97, 50, 45, 40, 89],
#        [73, 37,  0, 18, 23]])

# %%
avg = np.mean(Gamma[:,1])
avg
# Out:
# 38.8

# %%
np.add.reduce(Gamma[:,2]) + np.add.reduce(Gamma[:,3])
# Out:
# 1808

# %% [markdown]
# # **Exercises for Participation Credit (Continued)**
#
# We will now use a simple IoT readings dataset for this exercise. This dataset contains IoT temperature readings, where the reading was made (room) and location (reading was outside or inside a room).
#
# 4. Open the data file IOT-temp.csv inside the iotdata-compressed file, you will need some program like 7zip or Winrar to uncompress this iotdata-compressed folder. Open this file with Pandas and create a new Dataframe with this data. Show the first 10 rows of data. Show the last 10 rows of data. Show data points for index 300 to 350.
#
# 5. Create a new dataframe from index 1000 to 2000. Rename column out/in to location. Rename colum room_id/id to room How many of these readings were made outside? How many were inside?
#
# 6. Split your new dataframe into readings that were made inside and readings that were made outside. Create a new dataframe with only inside readings. Create a new dataframe only with outside readings. Print the mean value of the temperature for both new dataframes.
#
# 7. Save both dataframes created in exercise 6 to csv files.
#
# More information about the dataset for exercises 4 and 5 in this link

# %%
import pandas as pd

# %%
# %%capture
def Fdata():
  import os, shutil
  cwd = os.getcwd()
  if os.path.exists("LSAMP_Python"):
    shutil.rmtree("LSAMP_Python")
  # !git clone https://github.com/DanielaaVargas/LSAMP_Python.git
  for file in os.listdir("LSAMP_Python"):
    if file.endswith((".csv")):
      shutil.copy("LSAMP_Python/{}".format(file),cwd)
Fdata()

# %%
IOTtemp = pd.read_csv("IOT-temp.csv")
IOTtemp.head(10)
# Out:
#                                     id  room_id/id        noted_date  temp  \
# 0  __export__.temp_log_196134_bd201015  Room Admin  08-12-2018 09:30    29
# 1  __export__.temp_log_196131_7bca51bc  Room Admin  08-12-2018 09:30    29
# 2  __export__.temp_log_196127_522915e3  Room Admin  08-12-2018 09:29    41
# 3  __export__.temp_log_196128_be0919cf  Room Admin  08-12-2018 09:29    41
# 4  __export__.temp_log_196126_d30b72fb  Room Admin  08-12-2018 09:29    31
# 5  __export__.temp_log_196125_b0fa0b41  Room Admin  08-12-2018 09:29    31
# 6  __export__.temp_log_196121_01544d45  Room Admin  08-12-2018 09:28    29
# 7  __export__.temp_log_196122_f8b80a9f  Room Admin  08-12-2018 09:28    29
# 8  __export__.temp_log_196111_6b7a0848  Room Admin  08-12-2018 09:26    29
# 9  __export__.temp_log_196112_e134aebd  Room Admin  08-12-2018 09:26    29
#
#   out/in
# 0     In
# 1     In
# 2    Out
# 3    Out
# 4     In
# 5     In
# 6     In
# 7     In
# 8     In
# 9     In

# %%
IOTtemp.tail(10)
# Out:
#                                         id  room_id/id        noted_date  \
# 97596  __export__.temp_log_111718_05b8d88d  Room Admin  28-07-2018 07:07
# 97597   __export__.temp_log_96677_28b0568f  Room Admin  28-07-2018 07:07
# 97598  __export__.temp_log_110269_898976fc  Room Admin  28-07-2018 07:07
# 97599  __export__.temp_log_124155_da310d7b  Room Admin  28-07-2018 07:07
# 97600  __export__.temp_log_121414_9004c748  Room Admin  28-07-2018 07:07
# 97601   __export__.temp_log_91076_7fbd08ca  Room Admin  28-07-2018 07:07
# 97602  __export__.temp_log_147733_62c03f31  Room Admin  28-07-2018 07:07
# 97603  __export__.temp_log_100386_84093a68  Room Admin  28-07-2018 07:06
# 97604  __export__.temp_log_123297_4d8e690b  Room Admin  28-07-2018 07:06
# 97605  __export__.temp_log_133741_32958703  Room Admin  28-07-2018 07:06
#
#        temp out/in
# 97596    32    Out
# 97597    31     In
# 97598    31     In
# 97599    32    Out
# 97600    31     In
# 97601    31     In
# 97602    31     In
# ...

# %%
IOTtemp.iloc[300:351]
# Out:
#                                       id  room_id/id        noted_date  temp  \
# 300  __export__.temp_log_195177_d33112e6  Room Admin  08-12-2018 04:20    36
# 301  __export__.temp_log_195176_b9e9dbb5  Room Admin  08-12-2018 04:19    36
# 302  __export__.temp_log_195175_07586658  Room Admin  08-12-2018 04:19    29
# 303  __export__.temp_log_195174_72be5b21  Room Admin  08-12-2018 04:19    29
# 304  __export__.temp_log_195167_e8fa1d81  Room Admin  08-12-2018 04:18    36
# 305  __export__.temp_log_195166_abde5476  Room Admin  08-12-2018 04:17    36
# 306  __export__.temp_log_195165_99840a1c  Room Admin  08-12-2018 04:17    29
# 307  __export__.temp_log_195164_4ff2549b  Room Admin  08-12-2018 04:17    29
# 308  __export__.temp_log_195158_b42b3e8b  Room Admin  08-12-2018 04:16    37
# 309  __export__.temp_log_195159_f47207dc  Room Admin  08-12-2018 04:15    37
# 310  __export__.temp_log_195153_1fbbf291  Room Admin  08-12-2018 04:14    37
# ...

# %%
DataF = IOTtemp.iloc[1000:2001]
DataF
# Out:
#                                        id  room_id/id        noted_date  temp  \
# 1000  __export__.temp_log_193515_7c7f482c  Room Admin  07-12-2018 18:20    29
# 1001  __export__.temp_log_193514_04dce9c2  Room Admin  07-12-2018 18:20    29
# 1002  __export__.temp_log_193511_26e001f0  Room Admin  07-12-2018 18:18    38
# 1003  __export__.temp_log_193510_9b2d9c4d  Room Admin  07-12-2018 18:18    38
# 1004  __export__.temp_log_193509_47e74171  Room Admin  07-12-2018 18:18    29
# ...                                   ...         ...               ...   ...
# 1996  __export__.temp_log_190700_598349c7  Room Admin  07-12-2018 01:25    33
# 1997  __export__.temp_log_190699_439d5931  Room Admin  07-12-2018 01:25    33
# 1998  __export__.temp_log_190698_b2f37148  Room Admin  07-12-2018 01:23    32
# 1999  __export__.temp_log_190697_25aef9b9  Room Admin  07-12-2018 01:23    32
# 2000  __export__.temp_log_190694_11b48341  Room Admin  07-12-2018 01:21    31
#
#      out/in
# 1000     In
# ...

# %%
DataF.rename(columns={"out/in":"location", "room_id/id":"room"}, inplace=True)
DataF
# Out:
# <ipython-input-53-9d4a2ed76c9f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DataF.rename(columns={"out/in":"location", "room_id/id":"room"}, inplace=True)
#                                        id        room        noted_date  temp  \
# 1000  __export__.temp_log_193515_7c7f482c  Room Admin  07-12-2018 18:20    29
# 1001  __export__.temp_log_193514_04dce9c2  Room Admin  07-12-2018 18:20    29
# 1002  __export__.temp_log_193511_26e001f0  Room Admin  07-12-2018 18:18    38
# 1003  __export__.temp_log_193510_9b2d9c4d  Room Admin  07-12-2018 18:18    38
# 1004  __export__.temp_log_193509_47e74171  Room Admin  07-12-2018 18:18    29
# ...                                   ...         ...               ...   ...
# 1996  __export__.temp_log_190700_598349c7  Room Admin  07-12-2018 01:25    33
# ...

# %%
DataIn = DataF.loc[DataF["location"]=="In"]
print(f'There were {len(DataIn)} measurements inside.')
# Out:
# There were 565 measurements inside.

# %%
DataOut = DataF.loc[DataF["location"]=="Out"]
print(f'There were {len(DataOut)} measurements outside.')
# Out:
# There were 436 measurements outside.

# %%
print(DataIn)
# Out:
#                                        id        room        noted_date  temp  \
# 1000  __export__.temp_log_193515_7c7f482c  Room Admin  07-12-2018 18:20    29
# 1001  __export__.temp_log_193514_04dce9c2  Room Admin  07-12-2018 18:20    29
# 1004  __export__.temp_log_193509_47e74171  Room Admin  07-12-2018 18:18    29
# 1005  __export__.temp_log_193508_041bf6bc  Room Admin  07-12-2018 18:18    29
# 1006  __export__.temp_log_193503_e8b2d4aa  Room Admin  07-12-2018 18:16    29
# ...                                   ...         ...               ...   ...
# 1963  __export__.temp_log_190820_fdda325d  Room Admin  07-12-2018 02:27    31
# 1966  __export__.temp_log_190799_6401ad73  Room Admin  07-12-2018 02:19    30
# 1967  __export__.temp_log_190800_3ffc2c5f  Room Admin  07-12-2018 02:19    30
# 1968  __export__.temp_log_190793_cb29f220  Room Admin  07-12-2018 02:17    29
# 1969  __export__.temp_log_190794_08d54ca2  Room Admin  07-12-2018 02:17    29
#
#      location
# 1000       In
# ...

# %%
Itemp = DataIn['temp']
Itemp.mean()
# Out:
# 28.486725663716815

# %%
Otemp = DataOut['temp']
Otemp.mean()
# Out:
# 35.96559633027523

# %%
DataIn.to_csv("Inside.csv")
DataOut.to_csv("Outside.csv")

# %%
import os
print(os.getcwd())
# Out:
# /content
